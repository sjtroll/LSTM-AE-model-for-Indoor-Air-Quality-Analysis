# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Previous data
models = [
    "1L-16U", "1L-32U", "1L-64U","1L-128U", "2L-(16,32)U", "2L-(16,64)U", 
    "2L-(32,64)U", "3L-(16,32,168)U", "3L-(16,32,64)U", "3L-(16,32,128)U"
]
accuracy = [
    0.9715745471435207, 0.9631831552871961, 0.9558445579811117, 0.9516953088713423, 0.9715435825979254, 
    0.9713887598699489, 0.9677349434897042, 0.9690664189503019, 0.9707075398668524, 0.9669917943954173
]
precision = [
    0.9958984875672905, 0.9966869133075649, 0.9979259259259259, 0.9993809965954813, 0.9961518727552591, 
    0.9961469303878757, 0.9960264900662251, 0.9960712414876899, 0.9961250322913976, 0.9967957276368491
]
recall = [
    0.811573010236056, 0.7541257572592438, 0.703572174639649, 0.6745351994986422, 0.8111552120325882, 
    0.810110716523919, 0.7854606225193231, 0.7944432838938793, 0.805514936285774, 0.7798203467725089
]
f1_score = [
    0.8943370165745855, 0.8586038767986681, 0.8252879196275422, 0.8054377650286855, 0.8941853770869316, 
    0.8935483870967741, 0.8782994627423499, 0.88390470656595, 0.8907368907368908, 0.8750586029067041
]

# %%
# Plotting
plt.figure(figsize=(14, 8))
plt.plot(models, accuracy, marker='o', label='Accuracy')
plt.plot(models, precision, marker='o', label='Precision')
plt.plot(models, recall, marker='o', label='Recall')
plt.plot(models, f1_score, marker='o', label='F1 Score')

# Labeling the chart
plt.xlabel('Model Architecture')
plt.ylabel('Score')
plt.title('Performance Metrics for Different LSTM-AE Architectures')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.tight_layout()
plt.show()

# %%
time_per_epoch = [47.47, 44.9, 44.77, 50.20 ,75.83, 76.77, 75.77, 111.77, 105.67, 110.47]
models = ["1L-16U", "1L-32U", "1L-64U","1L-128U" ,"2L-(16,32)U", "2L-(16,64)U", "2L-(32,64)U", "3L-(16,32,168)U", "3L-(16,32,64)U", "3L-(16,32,128)U"]
# Plotting the data
plt.figure(figsize=(12, 6))
plt.plot(models, time_per_epoch, marker='o', linestyle='-', color='b')
plt.title("Time per Epoch for Different Model Architectures")
plt.xlabel("Model Architecture")
plt.ylabel("Time per Epoch (seconds)")
plt.xticks(rotation=45)
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.tight_layout()

# Display the plot
plt.show()

# %%
# Define the window sizes and the corresponding performance metrics
window_sizes = [5, 10, 15, 20, 25, 30, 35,40]
accuracy = [0.9666, 0.9698, 0.9642, 0.9619, 0.9595, 0.9549, 0.9519, 0.9494]
precision = [1.0, 0.9961, 0.9892, 0.9813, 0.9736, 0.9667, 0.9575, 0.9464]
recall = [0.7746, 0.7995, 0.7669, 0.7573, 0.7470, 0.7209, 0.7065, 0.6983]
f1_score = [0.8730, 0.8870, 0.8640, 0.8549, 0.8454, 0.8259, 0.8131, 0.8037]

# Plot the performance metrics against window sizes
plt.figure(figsize=(10,6))
plt.plot(window_sizes, accuracy, marker='o', label='Accuracy')
plt.plot(window_sizes, precision, marker='o', label='Precision')
plt.plot(window_sizes, recall, marker='o', label='Recall')
plt.plot(window_sizes, f1_score, marker='o', label='F1 Score')

# Add labels and title
plt.xlabel('Window Size')
plt.ylabel('Score')
plt.title('Performance of LSTM-AE Model for Different Window Sizes')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
dropout_rates = [0.1, 0.2, 0.5, 0.6, 0.7]
accuracy = [0.9657532125716055, 0.9682923053104195, 0.9740207462455488, 0.9926304381483202, 0.9935593745161789]
precision = [0.9964931211222012, 0.996831264853446, 0.9964788732394366, 0.9856929318812727, 0.9754932502596054]
recall = [0.7716732818048883, 0.7885941090453311, 0.8276582410695634, 0.9642782536035095, 0.9811990808439524]
f1_score = [0.8697904403108077, 0.880569162584558, 0.9042565331507475, 0.9748680042238648, 0.9783378462820246]

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(dropout_rates, accuracy, marker='o', label='Accuracy')
plt.plot(dropout_rates, precision, marker='o', label='Precision')
plt.plot(dropout_rates, recall, marker='o', label='Recall')
plt.plot(dropout_rates, f1_score, marker='o', label='F1 Score')
plt.title('Model Performance vs. Dropout Rate')
plt.xlabel('Dropout Rate')
plt.ylabel('Score')
plt.legend()
plt.grid(True)
plt.show()

# %%
import seaborn as sns

# Data
dropout_rates = [0.7, 0.6, 0.5, 0.2, 0.1]
accuracy = [0.9935593745161789, 0.9926304381483202, 0.9740207462455488, 0.971295866233163, 0.9657532125716055]
precision = [0.9754932502596054, 0.9856929318812727, 0.9964788732394366, 0.9961439588688946, 0.9964931211222012]
recall = [0.9811990808439524, 0.9642782536035095, 0.8276582410695634, 0.8094840192187174, 0.7716732818048883]
f1_score = [0.9783378462820246, 0.9748680042238648, 0.9042565331507475, 0.8931658407283622, 0.8697904403108077]

# Plotting
plt.figure(figsize=(12, 8))

# Line plots for each metric
for metric, values in zip(['Accuracy', 'Precision', 'Recall', 'F1 Score'], [accuracy, precision, recall, f1_score]):
    sns.lineplot(x=dropout_rates, y=values, label=metric, marker='o')

plt.title('Performance Metrics vs. Dropout Rate')
plt.xlabel('Dropout Rate')
plt.ylabel('Value')
plt.legend()
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.tight_layout()
plt.show()
